# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page
import pandas as pd
# !pip uninstall pandasql

# %%
match_schedule_html = open('match_schedule_html.txt', 'r')
soup = BeautifulSoup(match_schedule_html, 'lxml')
match_schedule_html.close()

# %%
table = soup.select('table.schedtbl')[0]
table_df = pd.DataFrame()
table_df = pd.read_html(str(table))[0]
table_df.drop(0, axis=0, inplace=True)
table_df.to_csv('match_schedule_2022.csv', index=False)
table_df
# Out:
#        M             Date                                         Match  \
# 1    2.0  Sun 29 May 2022              Panthers VS. Tricounty Scorecard
# 2    3.0  Sun 29 May 2022               Smashers VS. Wildfiya Scorecard
# 3    4.0  Sun 29 May 2022               Fuzion SC VS. Pegasus Scorecard
# 4    5.0  Sun 29 May 2022    11 Man Army VS. Brampton Rangers Scorecard
# 5    6.0  Sun 29 May 2022  Enterprise VS. Brampton Gladiators Scorecard
# ..   ...              ...                                           ...
# 77  78.0  Sun 14 Aug 2022    Enterprise VS. Aces Cricket Club Scorecard
# 78  79.0  Sun 14 Aug 2022       Wildfiya VS. Brampton Rangers Scorecard
# 79  80.0  Sun 14 Aug 2022         Cool Runningz VS. Tricounty Scorecard
# 80  81.0  Sun 14 Aug 2022         Industry CC VS. 11 Man Army Scorecard
# 81  82.0  Sun 14 Aug 2022          Paris Sunshine VS. Pegasus Scorecard
#
#     Venue No.                                           Location
# ...
